# %% [markdown]
# First part of the project is to pull real-world data from the **Youtube API**, instead of using existing static data from a database, like Kaggle.
#
# **Benefits** of using an API to extract data:
# * Real world skills in coding and analytics are exercised
# * Experience in modern technologies and tools gained
#
# Overview of the **steps**:
# - Pull the data
# - Look through the JSON response
# - Save the data in a pandas data frame

# %% [markdown]
# Starting with importing the necessary libraries, which include "requests" to make the API calls, "pandas" to save the data into a pandas dataframe and finally "time".

# %%
#import libraries
import requests
import pandas as pd
import time

# %% [markdown]
# What is an API?
#
#  The Application Programming Interface lists the operations and their desctription that a developer can use and defines how pieces of code interact with each other.
#
#  In Layman's terms, the API serves the same purpose as the waiter in a restaurant. They list the available choices and take an order, that is then transfered to the kitchen or system. From there the order is prepared, how is not our concern, and the waiter delivers the response back to us.

# %% [markdown]
# The **API key** is an important aspect that authenticates the user and allows to make the API calls to Youtube.
#
# Steps to create a Youtuve API key:
# * Visit Google Developers Console
# * Create a new projecy
# * Enable APIs and Services
# * Go to "Credentials" -> "Create Credentials" -> "API Key"

# %%
API_KEY = "insert_your_key"
CHANNEL_ID  = "UCW8Ews7tdKKkBT6GdtQaXvQ"

# %% [markdown]
# Making an **API call**
#
# To make a call to the API, the URL needs to be passed to the API. The URL is the location of the API and specifies the necessary data. The HTTP GET URL is found through the Youtuve Data API overview and this is only the root of the URL. The parameters will also need to be set depending on the data to be extracted.
#
# The following are the necessary parameters for the scope of this project:
#
# * snippet and id information
# * channel_id
# * maximum results
# * order the results by date
# * pageToken allows to go through all the pages of the results until all the videos are collected
#
# The get method makes the API call and grabs data from that call. The data will be returned in **JSON** form.
#
# A JSON object is a popular data file set as a javascript object and contains the data in an attribute/key-value pair.

# %%
pageToken=""
url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken

response = requests.get(url).json()

response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'WmqCtFXhmKf2vxhW_4fF2HV7AWw',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'NL',
#  'pageInfo': {'totalResults': 92, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': '_WQ1Gi8GAuGmDYFBWXBp9BpABVA',
#    'id': {'kind': 'youtube#video', 'videoId': 'tnoOz6MzTPg'},
#    'snippet': {'publishedAt': '2022-05-11T15:01:39Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Python cumsum() | Solving Python Optimization Questions On a Data Science Interview',
#     'description': "In this video, we'll take a close look at one of the larger families of data science questions concerning optimization. We'll use the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tnoOz6MzTPg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tnoOz6MzTPg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tnoOz6MzTPg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-05-11T15:01:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'hpAQvT0_YvExsk3olZrF8emmXKY',
#    'id': {'kind': 'youtube#video', 'videoId': 'OzyHfddLj9g'},
#    'snippet': {'publishedAt': '2022-04-13T03:26:28Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'How to Solve a SQL Interview Question Using WHERE &amp; HAVING | PayPal Data Science Interview',
#     'description': "In this video, we'll take a close look at one of the PayPal data scientist interview questions and discuss two different ways of ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OzyHfddLj9g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/OzyHfddLj9g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/OzyHfddLj9g/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-04-13T03:26:28Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 's1tr7m1aFScZW8QZ2gbyRJTfoWs',
#    'id': {'kind': 'youtube#video', 'videoId': 'jN5hpgBrz8k'},
#    'snippet': {'publishedAt': '2022-03-22T17:30:06Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Dealing With Python Date Manipulations In a Meta/Facebook Data Science Interview Question',
#     'description': 'This is a really interesting Python question that is frequently asked at Meta/Facebook data science interviews. The title of this ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jN5hpgBrz8k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jN5hpgBrz8k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/jN5hpgBrz8k/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-22T17:30:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DoabSn3eH9_9Om_DMeWdilwbUs0',
#    'id': {'kind': 'youtube#video', 'videoId': 'yFyyP_Uvxj0'},
#    'snippet': {'publishedAt': '2022-03-10T02:52:23Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'How To Solve Data Science Probability Interview Questions | Meta/Facebook Example',
#     'description': "Top companies require top data scientists. The ones that are good at solving probability problems, which is what we'll do in this ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yFyyP_Uvxj0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yFyyP_Uvxj0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yFyyP_Uvxj0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-10T02:52:23Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'avf1ZKZSfZDzyysP1F28T4-80E4',
#    'id': {'kind': 'youtube#video', 'videoId': 'Av92CaPTRr8'},
#    'snippet': {'publishedAt': '2022-03-02T09:35:11Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'How to use SQL window functions: RANK vs DENSE_RANK in Data Science Interviews',
#     'description': "This video covers two of the most common SQL Rank Functions, their differences, and how to use them. We'll take the following ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Av92CaPTRr8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Av92CaPTRr8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Av92CaPTRr8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-03-02T09:35:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'tJStzweYNGk6fOiOaoSlH2YcTZk',
#    'id': {'kind': 'youtube#video', 'videoId': 'VEjxlKBkZGM'},
#    'snippet': {'publishedAt': '2022-02-08T03:13:06Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Amazon Data Science Interview Question Walkthrough | How to Deal with Streaks in SQL',
#     'description': 'This walkthrough has been requested by multiple users on StrataScratch as it seems to have become quite a popular question.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VEjxlKBkZGM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VEjxlKBkZGM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VEjxlKBkZGM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-02-08T03:13:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'nOtWObH3Es3x2brkwfWPXTTyxTM',
#    'id': {'kind': 'youtube#video', 'videoId': 'hMUf7DqG1nQ'},
#    'snippet': {'publishedAt': '2022-01-27T06:23:05Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'SQL Basics: How to Join Multiple Tables in SQL and the Importance of LEFT JOIN vs INNER JOIN',
#     'description': "In this video, We will show you how to join multiple tables in SQL and the importance of LEFT JOIN vs INNER JOIN. We'll also talk ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hMUf7DqG1nQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/hMUf7DqG1nQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/hMUf7DqG1nQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-27T06:23:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '6pXgw5-2qMai13Lja6-cpFCY1XQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'ToEl_tpyoM4'},
#    'snippet': {'publishedAt': '2022-01-10T05:46:03Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Uber Data Science Python Interview Question Walkthrough',
#     'description': 'In this video, we will take a close look at a difficult data science interview question from Uber and walk you through a solution in ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ToEl_tpyoM4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/ToEl_tpyoM4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/ToEl_tpyoM4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2022-01-10T05:46:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CERQ39l6kcAa6p-feee2p8jU_bw',
#    'id': {'kind': 'youtube#video', 'videoId': '30hS-MjpU6E'},
#    'snippet': {'publishedAt': '2021-12-22T03:32:13Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'SQL Syntax Best Practices: How to Structure Your SQL Code',
#     'description': 'SQL is not just about writing queries, you also need to make sure that your queries are performant, fast, and readable. This video ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/30hS-MjpU6E/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/30hS-MjpU6E/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/30hS-MjpU6E/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-12-22T03:32:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'gMklx_zhyknebGkeQOn5O3hS8xc',
#    'id': {'kind': 'youtube#video', 'videoId': 'Bgpp99iz0I0'},
#    'snippet': {'publishedAt': '2021-11-04T01:53:13Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Most Common Coding Mistakes on Data Science Interviews',
#     'description': 'In this video, we will see the most common coding mistakes candidates make when answering SQL questions during their ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bgpp99iz0I0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Bgpp99iz0I0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Bgpp99iz0I0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-11-04T01:53:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'SIKc8dXMFMMZiuIQ9I-vMlHrTWk',
#    'id': {'kind': 'youtube#video', 'videoId': 'GeJUvdkJKEc'},
#    'snippet': {'publishedAt': '2021-10-11T06:50:13Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Multiple Solutions to Data Scientist Interview Question From Amazon [Rolling Average]',
#     'description': "This data scientist interview question comes from Amazon and it's really an interesting question that deals with rolling average, the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GeJUvdkJKEc/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GeJUvdkJKEc/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GeJUvdkJKEc/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-10-11T06:50:13Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'u-0z_azsW40PX7Sg40sCo2B0iW4',
#    'id': {'kind': 'youtube#video', 'videoId': 'GGURenNfXI0'},
#    'snippet': {'publishedAt': '2021-09-13T06:06:10Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Multiple Approaches for Solving a Twitter Data Scientist Interview Question',
#     'description': "We'll closely examine one of the interesting Twitter data scientist interview questions that deal with finding the maximum values in ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GGURenNfXI0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/GGURenNfXI0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/GGURenNfXI0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-09-13T06:06:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'JuOxuqv6Hr4HVWqoKsU-VrxFj6E',
#    'id': {'kind': 'youtube#video', 'videoId': 'PlpUo6bHsBQ'},
#    'snippet': {'publishedAt': '2021-08-09T02:18:01Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Advanced Facebook Data Science SQL interview question [RANK()]',
#     'description': 'This advanced SQL question is from the Facebook data science interview that tests your ability to write window functions and rank ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-08-09T02:18:01Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MwG11LSUJEgSmQqXm-02441C_Ak',
#    'id': {'kind': 'youtube#video', 'videoId': 'uY2wfR8Dkqo'},
#    'snippet': {'publishedAt': '2021-07-26T03:43:39Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': '5 Tips for a Successful Data Science Interview',
#     'description': "In this video of 5 tips for a successful data science interview, I've teamed up with a couple of data scientists from the YouTube ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uY2wfR8Dkqo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/uY2wfR8Dkqo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/uY2wfR8Dkqo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-26T03:43:39Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '98guzlD3IL7747B1qQ2ZMjggNbE',
#    'id': {'kind': 'youtube#video', 'videoId': 'yY7yau9j3xk'},
#    'snippet': {'publishedAt': '2021-07-20T05:18:03Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Data Science SQL Scenario Based Interview Question [Facebook] - Date Manipulation',
#     'description': 'This Data Science SQL interview question is from Facebook, and tests your ability to filter out data based on date conditionals.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yY7yau9j3xk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/yY7yau9j3xk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/yY7yau9j3xk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-20T05:18:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Sne-bKCo1iRr99vENO8_s1obC8E',
#    'id': {'kind': 'youtube#video', 'videoId': 'i-E4pdU2qXM'},
#    'snippet': {'publishedAt': '2021-07-13T01:34:56Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Data Science SQL Interview Question Walkthrough [Microsoft] - Window Function: Ranking',
#     'description': "This Data Science SQL interview question is from Microsoft, and tests your ability to write window functions to rank data. I'll walk ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i-E4pdU2qXM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/i-E4pdU2qXM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/i-E4pdU2qXM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-07-13T01:34:56Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'QpdeH7pKS1Z6zHn-Rexyw1sWYFY',
#    'id': {'kind': 'youtube#video', 'videoId': 'T1UhSuKqy3A'},
#    'snippet': {'publishedAt': '2021-06-15T05:10:20Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Most Common Data Science SQL Interview Question from DoorDash [window functions &amp; partitions]',
#     'description': 'This is the most common data science SQL interview question from DoorDash, a food delivery company. This question tests your ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/T1UhSuKqy3A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/T1UhSuKqy3A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/T1UhSuKqy3A/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-15T05:10:20Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'oyAMI1w8x9itxyYoszaDAaha1bs',
#    'id': {'kind': 'youtube#video', 'videoId': '2iE3JgNTwVU'},
#    'snippet': {'publishedAt': '2021-06-04T05:36:49Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'A Walkthrough of Data Science SQL Interview Question from Noom (Date Manipulations)',
#     'description': 'This data science SQL interview question is from Noom that tests your ability to filter out data based on date conditionals.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2iE3JgNTwVU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2iE3JgNTwVU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2iE3JgNTwVU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-06-04T05:36:49Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'COzc8KKGQaAa_pjrfXnjVwLayMM',
#    'id': {'kind': 'youtube#video', 'videoId': 'RgKMbpEylWA'},
#    'snippet': {'publishedAt': '2021-05-24T05:01:10Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Comparing FAANG vs Non-FAANG Data Science Interview Questions',
#     'description': "In this video, we'll compare data science interview questions between FAANG and non-FAANG companies to uncover the ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RgKMbpEylWA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RgKMbpEylWA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RgKMbpEylWA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-05-24T05:01:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'DjquEdylv3-JDU9SFhKQO-DqKgc',
#    'id': {'kind': 'youtube#video', 'videoId': 'giGIPINLqJs'},
#    'snippet': {'publishedAt': '2021-05-13T06:23:40Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'An Analysis of 900 Data Science Interview Questions | Data Science Interview Guide',
#     'description': "In this video, we're analyzing 900 data science interview questions collected from a list of over 150 companies. I'll take you ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/giGIPINLqJs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/giGIPINLqJs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/giGIPINLqJs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-05-13T06:23:40Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '3hvT8brd8i6vaxb2NRz2ax9LrHw',
#    'id': {'kind': 'youtube#video', 'videoId': '77IVf0zgmwI'},
#    'snippet': {'publishedAt': '2021-05-05T17:55:05Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Importing a Pandas Dataframe to a Database in Python [For Your Data Science Project]',
#     'description': "Today we're going to talk about how to upload your data from a pandas dataframe to a database in the cloud. This is a ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/77IVf0zgmwI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/77IVf0zgmwI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/77IVf0zgmwI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-05-05T17:55:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'GbDIjSmRB8gAp-Z7QzUpQJah26I',
#    'id': {'kind': 'youtube#video', 'videoId': 'xtbMCAVXDmU'},
#    'snippet': {'publishedAt': '2021-04-15T10:49:41Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Facebook and Microsoft Data Science SQL interview question walkthrough (advanced)',
#     'description': 'This data science SQL interview question is from Facebook and Microsoft that tests your ability to find and segment users as well ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xtbMCAVXDmU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/xtbMCAVXDmU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/xtbMCAVXDmU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-04-15T10:49:41Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'PgKa8pETLeRm9en_KrToA7CE0vE',
#    'id': {'kind': 'youtube#video', 'videoId': 'fklHBWow8vE'},
#    'snippet': {'publishedAt': '2021-04-02T03:05:38Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Working with APIs in Python [For Your Data Science Project]',
#     'description': "We're going to be working with the Youtube API to collect video statistics from my channel using the requests python library to ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fklHBWow8vE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fklHBWow8vE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fklHBWow8vE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-04-02T03:05:38Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zXBIXduJJXyCon89Ud7UxknAKqo',
#    'id': {'kind': 'youtube#video', 'videoId': 'tNXliLTlrV8'},
#    'snippet': {'publishedAt': '2021-03-24T18:30:06Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Step-by-step Approach to Solving Any Data Science SQL Interview Question (Twitch)',
#     'description': "Here's a step-by-step framework to solve any data science SQL interview question. We'll cover a brand new data science ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tNXliLTlrV8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/tNXliLTlrV8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/tNXliLTlrV8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-03-24T18:30:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_1SIuIj4C1aWp8Jaf18dbpNJRAk',
#    'id': {'kind': 'youtube#video', 'videoId': 'XRwxYOhHdE8'},
#    'snippet': {'publishedAt': '2021-03-10T18:30:07Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Facebook&#39;s Most Common Data Science SQL Interview Question [2021 Interview Question and Answer]',
#     'description': "This is the most common data science interview question from Facebook. It's the most commonly tested concept on Facebook's ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XRwxYOhHdE8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XRwxYOhHdE8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XRwxYOhHdE8/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-03-10T18:30:07Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'YF5aLTduoaWy35yCLJxJ9b3lxms',
#    'id': {'kind': 'youtube#video', 'videoId': 'pV_mnZgzXEo'},
#    'snippet': {'publishedAt': '2021-03-03T18:30:05Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Coding Concepts in Data Science Interviews in 2021 (Facebook, Twitch, Postmates)',
#     'description': "In this video, we'll talk about the 5 coding concepts that companies will test you on in data science interviews in 2021. As you guys ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pV_mnZgzXEo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pV_mnZgzXEo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pV_mnZgzXEo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-03-03T18:30:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'yv6UJm2hnSFfGSD8UZbmchQSPik',
#    'id': {'kind': 'youtube#video', 'videoId': 'c4Af2FcgamA'},
#    'snippet': {'publishedAt': '2021-02-24T18:30:11Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'The One and Only Data Science Project You Need',
#     'description': "Are you trying to figure out your next data science project? Find the one and only project that you need to build, that'll help you ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/c4Af2FcgamA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/c4Af2FcgamA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/c4Af2FcgamA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-02-24T18:30:11Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Dmq2VC8JhB2-dfkwNWB3LsUjpao',
#    'id': {'kind': 'youtube#video', 'videoId': 'QenwDm5oWdU'},
#    'snippet': {'publishedAt': '2021-02-17T18:30:02Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Advanced Data Science SQL Interview Question [Amazon] (window functions &amp; aliasing)',
#     'description': 'This SQL data science interview question was asked by Amazon and will test your date manipulation and window function skills.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QenwDm5oWdU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/QenwDm5oWdU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/QenwDm5oWdU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-02-17T18:30:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'CBWWNnns2ZutgPtf1omErA2jwHw',
#    'id': {'kind': 'youtube#video', 'videoId': 'TYHWv1vT0Pk'},
#    'snippet': {'publishedAt': '2021-02-11T08:00:16Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Common Date Manipulations on Data Science SQL Interviews',
#     'description': 'Date and datetime manipulations are really common and necessary to do data science work. The skill and concepts are often ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TYHWv1vT0Pk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TYHWv1vT0Pk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TYHWv1vT0Pk/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-02-11T08:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'Lh5hYU5bl2VPFmCZs0eCIjg6Bm0',
#    'id': {'kind': 'youtube#video', 'videoId': '0GpgMvyN0Fg'},
#    'snippet': {'publishedAt': '2021-02-04T08:00:02Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'How I Learned Data Science (resources to get a job) in 2021',
#     'description': "Let's talk about how to learn data science. Or at least, how I learned data science. I'll go over the topics I think are important like ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0GpgMvyN0Fg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/0GpgMvyN0Fg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/0GpgMvyN0Fg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-02-04T08:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'MpMu021jxj-HWE73x_0DMhoVQ7w',
#    'id': {'kind': 'youtube#video', 'videoId': 'VYeevsVj4fU'},
#    'snippet': {'publishedAt': '2021-01-27T08:00:17Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Advanced SQL Questions From Amazon (Handling complex logic in data science interviews)',
#     'description': 'This SQL question involves handling complex logic and implementing multiple scenarios and edge cases that can leave a new ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VYeevsVj4fU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/VYeevsVj4fU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/VYeevsVj4fU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-01-27T08:00:17Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'E3dHdTPnRR36FweyC3vReQ5cgHs',
#    'id': {'kind': 'youtube#video', 'videoId': 'vLjAG9eXkcU'},
#    'snippet': {'publishedAt': '2021-01-20T08:00:30Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Solving Complex SQL Interview Questions [How to organize lengthy code solutions]',
#     'description': "Let's talk about a framework to organize lengthy SQL code on a data science interview or on the job. Most data science problems ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vLjAG9eXkcU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vLjAG9eXkcU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vLjAG9eXkcU/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-01-20T08:00:30Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ixLlq8GLOS82dxgUBVH_1IFa71U',
#    'id': {'kind': 'youtube#video', 'videoId': 'lG0PbUq4wkg'},
#    'snippet': {'publishedAt': '2021-01-13T08:00:21Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Top Data Science Interview Questions in 2021 [3 concepts tested on all interviews]',
#     'description': "We're going to go over the most common data science interview question for 2021 in this video. Really it's 3 of the most common ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lG0PbUq4wkg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/lG0PbUq4wkg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/lG0PbUq4wkg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-01-13T08:00:21Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'luwOY871ljSS7ZTTr3-qlBitXSY',
#    'id': {'kind': 'youtube#video', 'videoId': 'j8kGqAAIhxA'},
#    'snippet': {'publishedAt': '2021-01-06T08:00:09Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Top Data Science Interview Question And Answer Mistakes 2021 [Asked By Amazon]',
#     'description': "We're going to cover the #1 most common mistake made on data science interviews. This mistake is made by both inexperienced ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j8kGqAAIhxA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/j8kGqAAIhxA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/j8kGqAAIhxA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2021-01-06T08:00:09Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '8rvYp_DkTZH92AY4cyOju7MaZjI',
#    'id': {'kind': 'youtube#video', 'videoId': 'W_IERUwElkg'},
#    'snippet': {'publishedAt': '2020-12-28T08:00:18Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'SQL Case Statements For Data Science Interviews in 2021',
#     'description': "Let's cover 3 types of SQL case statements that show up on data science interviews and that you'd use daily as a data scientist.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/W_IERUwElkg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/W_IERUwElkg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/W_IERUwElkg/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-12-28T08:00:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'iLa7-zgCVLJID5rZYByfOIugyc8',
#    'id': {'kind': 'youtube#video', 'videoId': 'eC7MdwKCCOE'},
#    'snippet': {'publishedAt': '2020-12-22T08:00:18Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Tricky Data Science Interview Question [By Facebook]',
#     'description': "Today we'll cover a tricky data science interview question asked by Facebook. It's not so much a tricky problem as it is a problem ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eC7MdwKCCOE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/eC7MdwKCCOE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/eC7MdwKCCOE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-12-22T08:00:18Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'M3-sPnnEoPJcrWu8wlUSo2kp8sI',
#    'id': {'kind': 'youtube#video', 'videoId': 'XBE09l-UYTE'},
#    'snippet': {'publishedAt': '2020-12-17T08:00:16Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'SQL Window Functions on Data Science Interviews in 2021 | Asked By Airbnb, Netflix, Twitter, Uber',
#     'description': "Let's cover 4 SQL window function interview questions asked on Airbnb, Netflix, Twitter, and Uber data science interviews. I cover ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XBE09l-UYTE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XBE09l-UYTE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XBE09l-UYTE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-12-17T08:00:16Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'rBBzymJ7DdXmC4SLBfM2qNrtcx8',
#    'id': {'kind': 'youtube#video', 'videoId': 'C0hk-dZ9XSE'},
#    'snippet': {'publishedAt': '2020-12-10T08:00:02Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'SQL Window Functions In a Data Science Interview Question by Airbnb in 2021',
#     'description': 'SQL window functions are common data science and analytics coding interview questions. They also are used almost everyday at ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/C0hk-dZ9XSE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/C0hk-dZ9XSE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/C0hk-dZ9XSE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-12-10T08:00:02Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'O-9iEwBecz3zUsKpuzvXuvTg16k',
#    'id': {'kind': 'youtube#video', 'videoId': 'N0aHeKyNEto'},
#    'snippet': {'publishedAt': '2020-12-03T08:00:04Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Applying Software Engineering Principles To Your Data Science Tasks In Python',
#     'description': "We're going to apply software engineering fundamentals for this common data science tasks where we are going to finish ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/N0aHeKyNEto/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/N0aHeKyNEto/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/N0aHeKyNEto/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-12-03T08:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ca62RSziMVQHF1yhAf46SskcJGU',
#    'id': {'kind': 'youtube#video', 'videoId': 'TDwy1lSjEZo'},
#    'snippet': {'publishedAt': '2020-11-24T08:00:08Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Automating Your Data Science Tasks In Python (importing CSV files to database AUTOMATION TUTORIAL)',
#     'description': "This is part 2 on automating the import of CSV files to a database - a common data science task . In this video, we'll take our ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TDwy1lSjEZo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/TDwy1lSjEZo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/TDwy1lSjEZo/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-11-24T08:00:08Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'AAbqPDiVI5qos1vuVDeCmqaVVIk',
#    'id': {'kind': 'youtube#video', 'videoId': 'EPUayNC5ku4'},
#    'snippet': {'publishedAt': '2020-11-19T08:00:05Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'SQL Coding Interview Question Using A Window Function (PARTITION BY) | Data Science Interviews',
#     'description': "In this video, I'll walk you through a common SQL coding interview question that is asked in many data science interviews.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EPUayNC5ku4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/EPUayNC5ku4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/EPUayNC5ku4/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-11-19T08:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'FOxlfyQoK13WxY5RC0V2m4hfG6c',
#    'id': {'kind': 'youtube#video', 'videoId': 'wqBFgaMgFQA'},
#    'snippet': {'publishedAt': '2020-11-15T08:00:10Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Solve Data Science Tasks In Python (Saving Hours) (automating import CSV files to database)',
#     'description': "Solving real world data science tasks by automating this common data science task will save you hours of work. I'll cover how to ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wqBFgaMgFQA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wqBFgaMgFQA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wqBFgaMgFQA/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-11-15T08:00:10Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'd5lNxKgaxR9DRFawg9RABL1cxXQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'IKw0lkmBHNI'},
#    'snippet': {'publishedAt': '2020-11-11T08:00:06Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Solving an Airbnb Data Science Coding Interview Question | SQL Interview  [Fav Host Nationality]',
#     'description': "This SQL data science interview question was asked by Airbnb. I'll cover both the question and answer and give a detailed ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IKw0lkmBHNI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/IKw0lkmBHNI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/IKw0lkmBHNI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-11-11T08:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'ONkTSK_yMV5LFzXm0JrSBJ8Vlow',
#    'id': {'kind': 'youtube#video', 'videoId': '_gy1o9UH2dQ'},
#    'snippet': {'publishedAt': '2020-11-04T08:00:04Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Hard SQL Interview Question From FACEBOOK | Data Science Coding Interviews (Popularity Percentage)',
#     'description': "This SQL data science interview question was asked by Facebook. I'll cover both the question and answer and give a detailed ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_gy1o9UH2dQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/_gy1o9UH2dQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/_gy1o9UH2dQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-11-04T08:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '00C_n3Pwkdo-JauDL1cUq5MZZe8',
#    'id': {'kind': 'youtube#video', 'videoId': '7Q-2DEwHW7w'},
#    'snippet': {'publishedAt': '2020-10-29T07:00:03Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Solving a SQL Interview Question by FACEBOOK | (Data Science Interview) SMS Confirmations From Users',
#     'description': "This SQL data science interview question was asked by Facebook. I'll cover both the question and answer and give a detailed ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7Q-2DEwHW7w/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7Q-2DEwHW7w/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7Q-2DEwHW7w/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-10-29T07:00:03Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '_ZgrFTzGWBg_H1kDnPqhdHoRjeg',
#    'id': {'kind': 'youtube#video', 'videoId': 'pFwYjaeKFvQ'},
#    'snippet': {'publishedAt': '2020-10-22T07:00:06Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Solving a Facebook Data Science Interview Questions | (SQL Interview Questions and Answer)',
#     'description': "This SQL data science interview question was asked by Facebook. I'll cover both the question and answer and give a detailed ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pFwYjaeKFvQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/pFwYjaeKFvQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/pFwYjaeKFvQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-10-22T07:00:06Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': '1L7ZuTkLhb4tet_ZGsZlLyQcHlQ',
#    'id': {'kind': 'youtube#video', 'videoId': 'iR8FDQyCtnw'},
#    'snippet': {'publishedAt': '2020-10-20T07:00:05Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'SQL Interview Questions From MICROSOFT | Expensive Projects (Data Science Interview Questions)',
#     'description': "This SQL data science interview question was asked by Microsoft. I'll cover both the question and answer and give a detailed ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iR8FDQyCtnw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/iR8FDQyCtnw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/iR8FDQyCtnw/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-10-20T07:00:05Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'WTSVmLa04UasCVYQ97vceVCuw7k',
#    'id': {'kind': 'youtube#video', 'videoId': '1SgHHQeRuxs'},
#    'snippet': {'publishedAt': '2020-10-18T15:59:35Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'How I Prepare For My Data Science Interviews (From a Data Scientist)',
#     'description': "Hi Everyone! I've been wanting to make a video where I talk about how I prepare for MY data science interviews so you know how ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1SgHHQeRuxs/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/1SgHHQeRuxs/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/1SgHHQeRuxs/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-10-18T15:59:35Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'zkL-xkNhirvXpiQVc5KjLu-wvFo',
#    'id': {'kind': 'youtube#video', 'videoId': 'UndSRKwsxKM'},
#    'snippet': {'publishedAt': '2020-10-10T07:00:04Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'YELP SQL Data Science Interview Questions | Common Coding Question (Mock Interview Walkthrough)',
#     'description': "This SQL data science interview question was asked by Yelp. I'll cover both the question and answer and give a detailed ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UndSRKwsxKM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UndSRKwsxKM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UndSRKwsxKM/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-10-10T07:00:04Z'}},
#   {'kind': 'youtube#searchResult',
#    'etag': 'fXfJD-Pk3fkkFYKNod0FIxz1G_0',
#    'id': {'kind': 'youtube#video', 'videoId': 'U9P4M4EPTgI'},
#    'snippet': {'publishedAt': '2020-09-23T07:00:04Z',
#     'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#     'title': 'Intro to Real Data Science Interview Questions and Answers Series (Interview Walkthroughs)',
#     'description': "Hey Everyone! I just wanted to introduce a new set of videos where I'll walk through data science interview questions from real ...",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U9P4M4EPTgI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/U9P4M4EPTgI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/U9P4M4EPTgI/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': 'StrataScratch',
#     'liveBroadcastContent': 'none',
#     'publishTime': '2020-09-23T07:00:04Z'}}]}

# %% [markdown]
# Reading through the JSON object, "items" is identified as the key holding all the relevant video information to be examined.

# %%
response['items']
# Out:
# [{'kind': 'youtube#searchResult',
#   'etag': '_WQ1Gi8GAuGmDYFBWXBp9BpABVA',
#   'id': {'kind': 'youtube#video', 'videoId': 'tnoOz6MzTPg'},
#   'snippet': {'publishedAt': '2022-05-11T15:01:39Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Python cumsum() | Solving Python Optimization Questions On a Data Science Interview',
#    'description': "In this video, we'll take a close look at one of the larger families of data science questions concerning optimization. We'll use the ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tnoOz6MzTPg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/tnoOz6MzTPg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/tnoOz6MzTPg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-05-11T15:01:39Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'hpAQvT0_YvExsk3olZrF8emmXKY',
#   'id': {'kind': 'youtube#video', 'videoId': 'OzyHfddLj9g'},
#   'snippet': {'publishedAt': '2022-04-13T03:26:28Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'How to Solve a SQL Interview Question Using WHERE &amp; HAVING | PayPal Data Science Interview',
#    'description': "In this video, we'll take a close look at one of the PayPal data scientist interview questions and discuss two different ways of ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/OzyHfddLj9g/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/OzyHfddLj9g/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/OzyHfddLj9g/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-04-13T03:26:28Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 's1tr7m1aFScZW8QZ2gbyRJTfoWs',
#   'id': {'kind': 'youtube#video', 'videoId': 'jN5hpgBrz8k'},
#   'snippet': {'publishedAt': '2022-03-22T17:30:06Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Dealing With Python Date Manipulations In a Meta/Facebook Data Science Interview Question',
#    'description': 'This is a really interesting Python question that is frequently asked at Meta/Facebook data science interviews. The title of this ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jN5hpgBrz8k/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/jN5hpgBrz8k/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/jN5hpgBrz8k/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-03-22T17:30:06Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'DoabSn3eH9_9Om_DMeWdilwbUs0',
#   'id': {'kind': 'youtube#video', 'videoId': 'yFyyP_Uvxj0'},
#   'snippet': {'publishedAt': '2022-03-10T02:52:23Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'How To Solve Data Science Probability Interview Questions | Meta/Facebook Example',
#    'description': "Top companies require top data scientists. The ones that are good at solving probability problems, which is what we'll do in this ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yFyyP_Uvxj0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/yFyyP_Uvxj0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/yFyyP_Uvxj0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-03-10T02:52:23Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'avf1ZKZSfZDzyysP1F28T4-80E4',
#   'id': {'kind': 'youtube#video', 'videoId': 'Av92CaPTRr8'},
#   'snippet': {'publishedAt': '2022-03-02T09:35:11Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'How to use SQL window functions: RANK vs DENSE_RANK in Data Science Interviews',
#    'description': "This video covers two of the most common SQL Rank Functions, their differences, and how to use them. We'll take the following ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Av92CaPTRr8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Av92CaPTRr8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Av92CaPTRr8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-03-02T09:35:11Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'tJStzweYNGk6fOiOaoSlH2YcTZk',
#   'id': {'kind': 'youtube#video', 'videoId': 'VEjxlKBkZGM'},
#   'snippet': {'publishedAt': '2022-02-08T03:13:06Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Amazon Data Science Interview Question Walkthrough | How to Deal with Streaks in SQL',
#    'description': 'This walkthrough has been requested by multiple users on StrataScratch as it seems to have become quite a popular question.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VEjxlKBkZGM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/VEjxlKBkZGM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/VEjxlKBkZGM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-02-08T03:13:06Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'nOtWObH3Es3x2brkwfWPXTTyxTM',
#   'id': {'kind': 'youtube#video', 'videoId': 'hMUf7DqG1nQ'},
#   'snippet': {'publishedAt': '2022-01-27T06:23:05Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'SQL Basics: How to Join Multiple Tables in SQL and the Importance of LEFT JOIN vs INNER JOIN',
#    'description': "In this video, We will show you how to join multiple tables in SQL and the importance of LEFT JOIN vs INNER JOIN. We'll also talk ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/hMUf7DqG1nQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/hMUf7DqG1nQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/hMUf7DqG1nQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-01-27T06:23:05Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '6pXgw5-2qMai13Lja6-cpFCY1XQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'ToEl_tpyoM4'},
#   'snippet': {'publishedAt': '2022-01-10T05:46:03Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Uber Data Science Python Interview Question Walkthrough',
#    'description': 'In this video, we will take a close look at a difficult data science interview question from Uber and walk you through a solution in ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ToEl_tpyoM4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ToEl_tpyoM4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/ToEl_tpyoM4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2022-01-10T05:46:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'CERQ39l6kcAa6p-feee2p8jU_bw',
#   'id': {'kind': 'youtube#video', 'videoId': '30hS-MjpU6E'},
#   'snippet': {'publishedAt': '2021-12-22T03:32:13Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'SQL Syntax Best Practices: How to Structure Your SQL Code',
#    'description': 'SQL is not just about writing queries, you also need to make sure that your queries are performant, fast, and readable. This video ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/30hS-MjpU6E/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/30hS-MjpU6E/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/30hS-MjpU6E/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-12-22T03:32:13Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'gMklx_zhyknebGkeQOn5O3hS8xc',
#   'id': {'kind': 'youtube#video', 'videoId': 'Bgpp99iz0I0'},
#   'snippet': {'publishedAt': '2021-11-04T01:53:13Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Most Common Coding Mistakes on Data Science Interviews',
#    'description': 'In this video, we will see the most common coding mistakes candidates make when answering SQL questions during their ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Bgpp99iz0I0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/Bgpp99iz0I0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/Bgpp99iz0I0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-11-04T01:53:13Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'SIKc8dXMFMMZiuIQ9I-vMlHrTWk',
#   'id': {'kind': 'youtube#video', 'videoId': 'GeJUvdkJKEc'},
#   'snippet': {'publishedAt': '2021-10-11T06:50:13Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Multiple Solutions to Data Scientist Interview Question From Amazon [Rolling Average]',
#    'description': "This data scientist interview question comes from Amazon and it's really an interesting question that deals with rolling average, the ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GeJUvdkJKEc/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/GeJUvdkJKEc/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/GeJUvdkJKEc/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-10-11T06:50:13Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'u-0z_azsW40PX7Sg40sCo2B0iW4',
#   'id': {'kind': 'youtube#video', 'videoId': 'GGURenNfXI0'},
#   'snippet': {'publishedAt': '2021-09-13T06:06:10Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Multiple Approaches for Solving a Twitter Data Scientist Interview Question',
#    'description': "We'll closely examine one of the interesting Twitter data scientist interview questions that deal with finding the maximum values in ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/GGURenNfXI0/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/GGURenNfXI0/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/GGURenNfXI0/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-09-13T06:06:10Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'JuOxuqv6Hr4HVWqoKsU-VrxFj6E',
#   'id': {'kind': 'youtube#video', 'videoId': 'PlpUo6bHsBQ'},
#   'snippet': {'publishedAt': '2021-08-09T02:18:01Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Advanced Facebook Data Science SQL interview question [RANK()]',
#    'description': 'This advanced SQL question is from the Facebook data science interview that tests your ability to write window functions and rank ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/PlpUo6bHsBQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-08-09T02:18:01Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'MwG11LSUJEgSmQqXm-02441C_Ak',
#   'id': {'kind': 'youtube#video', 'videoId': 'uY2wfR8Dkqo'},
#   'snippet': {'publishedAt': '2021-07-26T03:43:39Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': '5 Tips for a Successful Data Science Interview',
#    'description': "In this video of 5 tips for a successful data science interview, I've teamed up with a couple of data scientists from the YouTube ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/uY2wfR8Dkqo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/uY2wfR8Dkqo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/uY2wfR8Dkqo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-26T03:43:39Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '98guzlD3IL7747B1qQ2ZMjggNbE',
#   'id': {'kind': 'youtube#video', 'videoId': 'yY7yau9j3xk'},
#   'snippet': {'publishedAt': '2021-07-20T05:18:03Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Data Science SQL Scenario Based Interview Question [Facebook] - Date Manipulation',
#    'description': 'This Data Science SQL interview question is from Facebook, and tests your ability to filter out data based on date conditionals.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/yY7yau9j3xk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/yY7yau9j3xk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/yY7yau9j3xk/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-20T05:18:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Sne-bKCo1iRr99vENO8_s1obC8E',
#   'id': {'kind': 'youtube#video', 'videoId': 'i-E4pdU2qXM'},
#   'snippet': {'publishedAt': '2021-07-13T01:34:56Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Data Science SQL Interview Question Walkthrough [Microsoft] - Window Function: Ranking',
#    'description': "This Data Science SQL interview question is from Microsoft, and tests your ability to write window functions to rank data. I'll walk ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/i-E4pdU2qXM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/i-E4pdU2qXM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/i-E4pdU2qXM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-07-13T01:34:56Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'QpdeH7pKS1Z6zHn-Rexyw1sWYFY',
#   'id': {'kind': 'youtube#video', 'videoId': 'T1UhSuKqy3A'},
#   'snippet': {'publishedAt': '2021-06-15T05:10:20Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Most Common Data Science SQL Interview Question from DoorDash [window functions &amp; partitions]',
#    'description': 'This is the most common data science SQL interview question from DoorDash, a food delivery company. This question tests your ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/T1UhSuKqy3A/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/T1UhSuKqy3A/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/T1UhSuKqy3A/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-06-15T05:10:20Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'oyAMI1w8x9itxyYoszaDAaha1bs',
#   'id': {'kind': 'youtube#video', 'videoId': '2iE3JgNTwVU'},
#   'snippet': {'publishedAt': '2021-06-04T05:36:49Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'A Walkthrough of Data Science SQL Interview Question from Noom (Date Manipulations)',
#    'description': 'This data science SQL interview question is from Noom that tests your ability to filter out data based on date conditionals.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2iE3JgNTwVU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/2iE3JgNTwVU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/2iE3JgNTwVU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-06-04T05:36:49Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'COzc8KKGQaAa_pjrfXnjVwLayMM',
#   'id': {'kind': 'youtube#video', 'videoId': 'RgKMbpEylWA'},
#   'snippet': {'publishedAt': '2021-05-24T05:01:10Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Comparing FAANG vs Non-FAANG Data Science Interview Questions',
#    'description': "In this video, we'll compare data science interview questions between FAANG and non-FAANG companies to uncover the ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RgKMbpEylWA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/RgKMbpEylWA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/RgKMbpEylWA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-05-24T05:01:10Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'DjquEdylv3-JDU9SFhKQO-DqKgc',
#   'id': {'kind': 'youtube#video', 'videoId': 'giGIPINLqJs'},
#   'snippet': {'publishedAt': '2021-05-13T06:23:40Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'An Analysis of 900 Data Science Interview Questions | Data Science Interview Guide',
#    'description': "In this video, we're analyzing 900 data science interview questions collected from a list of over 150 companies. I'll take you ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/giGIPINLqJs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/giGIPINLqJs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/giGIPINLqJs/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-05-13T06:23:40Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '3hvT8brd8i6vaxb2NRz2ax9LrHw',
#   'id': {'kind': 'youtube#video', 'videoId': '77IVf0zgmwI'},
#   'snippet': {'publishedAt': '2021-05-05T17:55:05Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Importing a Pandas Dataframe to a Database in Python [For Your Data Science Project]',
#    'description': "Today we're going to talk about how to upload your data from a pandas dataframe to a database in the cloud. This is a ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/77IVf0zgmwI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/77IVf0zgmwI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/77IVf0zgmwI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-05-05T17:55:05Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'GbDIjSmRB8gAp-Z7QzUpQJah26I',
#   'id': {'kind': 'youtube#video', 'videoId': 'xtbMCAVXDmU'},
#   'snippet': {'publishedAt': '2021-04-15T10:49:41Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Facebook and Microsoft Data Science SQL interview question walkthrough (advanced)',
#    'description': 'This data science SQL interview question is from Facebook and Microsoft that tests your ability to find and segment users as well ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/xtbMCAVXDmU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/xtbMCAVXDmU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/xtbMCAVXDmU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-04-15T10:49:41Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'PgKa8pETLeRm9en_KrToA7CE0vE',
#   'id': {'kind': 'youtube#video', 'videoId': 'fklHBWow8vE'},
#   'snippet': {'publishedAt': '2021-04-02T03:05:38Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Working with APIs in Python [For Your Data Science Project]',
#    'description': "We're going to be working with the Youtube API to collect video statistics from my channel using the requests python library to ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fklHBWow8vE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/fklHBWow8vE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/fklHBWow8vE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-04-02T03:05:38Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'zXBIXduJJXyCon89Ud7UxknAKqo',
#   'id': {'kind': 'youtube#video', 'videoId': 'tNXliLTlrV8'},
#   'snippet': {'publishedAt': '2021-03-24T18:30:06Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Step-by-step Approach to Solving Any Data Science SQL Interview Question (Twitch)',
#    'description': "Here's a step-by-step framework to solve any data science SQL interview question. We'll cover a brand new data science ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/tNXliLTlrV8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/tNXliLTlrV8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/tNXliLTlrV8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-03-24T18:30:06Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '_1SIuIj4C1aWp8Jaf18dbpNJRAk',
#   'id': {'kind': 'youtube#video', 'videoId': 'XRwxYOhHdE8'},
#   'snippet': {'publishedAt': '2021-03-10T18:30:07Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Facebook&#39;s Most Common Data Science SQL Interview Question [2021 Interview Question and Answer]',
#    'description': "This is the most common data science interview question from Facebook. It's the most commonly tested concept on Facebook's ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XRwxYOhHdE8/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/XRwxYOhHdE8/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/XRwxYOhHdE8/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-03-10T18:30:07Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'YF5aLTduoaWy35yCLJxJ9b3lxms',
#   'id': {'kind': 'youtube#video', 'videoId': 'pV_mnZgzXEo'},
#   'snippet': {'publishedAt': '2021-03-03T18:30:05Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Coding Concepts in Data Science Interviews in 2021 (Facebook, Twitch, Postmates)',
#    'description': "In this video, we'll talk about the 5 coding concepts that companies will test you on in data science interviews in 2021. As you guys ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pV_mnZgzXEo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/pV_mnZgzXEo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/pV_mnZgzXEo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-03-03T18:30:05Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'yv6UJm2hnSFfGSD8UZbmchQSPik',
#   'id': {'kind': 'youtube#video', 'videoId': 'c4Af2FcgamA'},
#   'snippet': {'publishedAt': '2021-02-24T18:30:11Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'The One and Only Data Science Project You Need',
#    'description': "Are you trying to figure out your next data science project? Find the one and only project that you need to build, that'll help you ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/c4Af2FcgamA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/c4Af2FcgamA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/c4Af2FcgamA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-02-24T18:30:11Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Dmq2VC8JhB2-dfkwNWB3LsUjpao',
#   'id': {'kind': 'youtube#video', 'videoId': 'QenwDm5oWdU'},
#   'snippet': {'publishedAt': '2021-02-17T18:30:02Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Advanced Data Science SQL Interview Question [Amazon] (window functions &amp; aliasing)',
#    'description': 'This SQL data science interview question was asked by Amazon and will test your date manipulation and window function skills.',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/QenwDm5oWdU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/QenwDm5oWdU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/QenwDm5oWdU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-02-17T18:30:02Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'CBWWNnns2ZutgPtf1omErA2jwHw',
#   'id': {'kind': 'youtube#video', 'videoId': 'TYHWv1vT0Pk'},
#   'snippet': {'publishedAt': '2021-02-11T08:00:16Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Common Date Manipulations on Data Science SQL Interviews',
#    'description': 'Date and datetime manipulations are really common and necessary to do data science work. The skill and concepts are often ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TYHWv1vT0Pk/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/TYHWv1vT0Pk/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/TYHWv1vT0Pk/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-02-11T08:00:16Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'Lh5hYU5bl2VPFmCZs0eCIjg6Bm0',
#   'id': {'kind': 'youtube#video', 'videoId': '0GpgMvyN0Fg'},
#   'snippet': {'publishedAt': '2021-02-04T08:00:02Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'How I Learned Data Science (resources to get a job) in 2021',
#    'description': "Let's talk about how to learn data science. Or at least, how I learned data science. I'll go over the topics I think are important like ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/0GpgMvyN0Fg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/0GpgMvyN0Fg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/0GpgMvyN0Fg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-02-04T08:00:02Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'MpMu021jxj-HWE73x_0DMhoVQ7w',
#   'id': {'kind': 'youtube#video', 'videoId': 'VYeevsVj4fU'},
#   'snippet': {'publishedAt': '2021-01-27T08:00:17Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Advanced SQL Questions From Amazon (Handling complex logic in data science interviews)',
#    'description': 'This SQL question involves handling complex logic and implementing multiple scenarios and edge cases that can leave a new ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/VYeevsVj4fU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/VYeevsVj4fU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/VYeevsVj4fU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-01-27T08:00:17Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'E3dHdTPnRR36FweyC3vReQ5cgHs',
#   'id': {'kind': 'youtube#video', 'videoId': 'vLjAG9eXkcU'},
#   'snippet': {'publishedAt': '2021-01-20T08:00:30Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Solving Complex SQL Interview Questions [How to organize lengthy code solutions]',
#    'description': "Let's talk about a framework to organize lengthy SQL code on a data science interview or on the job. Most data science problems ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vLjAG9eXkcU/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/vLjAG9eXkcU/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/vLjAG9eXkcU/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-01-20T08:00:30Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ixLlq8GLOS82dxgUBVH_1IFa71U',
#   'id': {'kind': 'youtube#video', 'videoId': 'lG0PbUq4wkg'},
#   'snippet': {'publishedAt': '2021-01-13T08:00:21Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Top Data Science Interview Questions in 2021 [3 concepts tested on all interviews]',
#    'description': "We're going to go over the most common data science interview question for 2021 in this video. Really it's 3 of the most common ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/lG0PbUq4wkg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/lG0PbUq4wkg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/lG0PbUq4wkg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-01-13T08:00:21Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'luwOY871ljSS7ZTTr3-qlBitXSY',
#   'id': {'kind': 'youtube#video', 'videoId': 'j8kGqAAIhxA'},
#   'snippet': {'publishedAt': '2021-01-06T08:00:09Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Top Data Science Interview Question And Answer Mistakes 2021 [Asked By Amazon]',
#    'description': "We're going to cover the #1 most common mistake made on data science interviews. This mistake is made by both inexperienced ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/j8kGqAAIhxA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/j8kGqAAIhxA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/j8kGqAAIhxA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2021-01-06T08:00:09Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '8rvYp_DkTZH92AY4cyOju7MaZjI',
#   'id': {'kind': 'youtube#video', 'videoId': 'W_IERUwElkg'},
#   'snippet': {'publishedAt': '2020-12-28T08:00:18Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'SQL Case Statements For Data Science Interviews in 2021',
#    'description': "Let's cover 3 types of SQL case statements that show up on data science interviews and that you'd use daily as a data scientist.",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/W_IERUwElkg/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/W_IERUwElkg/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/W_IERUwElkg/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-12-28T08:00:18Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'iLa7-zgCVLJID5rZYByfOIugyc8',
#   'id': {'kind': 'youtube#video', 'videoId': 'eC7MdwKCCOE'},
#   'snippet': {'publishedAt': '2020-12-22T08:00:18Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Tricky Data Science Interview Question [By Facebook]',
#    'description': "Today we'll cover a tricky data science interview question asked by Facebook. It's not so much a tricky problem as it is a problem ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/eC7MdwKCCOE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/eC7MdwKCCOE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/eC7MdwKCCOE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-12-22T08:00:18Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'M3-sPnnEoPJcrWu8wlUSo2kp8sI',
#   'id': {'kind': 'youtube#video', 'videoId': 'XBE09l-UYTE'},
#   'snippet': {'publishedAt': '2020-12-17T08:00:16Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'SQL Window Functions on Data Science Interviews in 2021 | Asked By Airbnb, Netflix, Twitter, Uber',
#    'description': "Let's cover 4 SQL window function interview questions asked on Airbnb, Netflix, Twitter, and Uber data science interviews. I cover ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XBE09l-UYTE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/XBE09l-UYTE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/XBE09l-UYTE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-12-17T08:00:16Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'rBBzymJ7DdXmC4SLBfM2qNrtcx8',
#   'id': {'kind': 'youtube#video', 'videoId': 'C0hk-dZ9XSE'},
#   'snippet': {'publishedAt': '2020-12-10T08:00:02Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'SQL Window Functions In a Data Science Interview Question by Airbnb in 2021',
#    'description': 'SQL window functions are common data science and analytics coding interview questions. They also are used almost everyday at ...',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/C0hk-dZ9XSE/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/C0hk-dZ9XSE/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/C0hk-dZ9XSE/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-12-10T08:00:02Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'O-9iEwBecz3zUsKpuzvXuvTg16k',
#   'id': {'kind': 'youtube#video', 'videoId': 'N0aHeKyNEto'},
#   'snippet': {'publishedAt': '2020-12-03T08:00:04Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Applying Software Engineering Principles To Your Data Science Tasks In Python',
#    'description': "We're going to apply software engineering fundamentals for this common data science tasks where we are going to finish ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/N0aHeKyNEto/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/N0aHeKyNEto/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/N0aHeKyNEto/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-12-03T08:00:04Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ca62RSziMVQHF1yhAf46SskcJGU',
#   'id': {'kind': 'youtube#video', 'videoId': 'TDwy1lSjEZo'},
#   'snippet': {'publishedAt': '2020-11-24T08:00:08Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Automating Your Data Science Tasks In Python (importing CSV files to database AUTOMATION TUTORIAL)',
#    'description': "This is part 2 on automating the import of CSV files to a database - a common data science task . In this video, we'll take our ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/TDwy1lSjEZo/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/TDwy1lSjEZo/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/TDwy1lSjEZo/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-11-24T08:00:08Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'AAbqPDiVI5qos1vuVDeCmqaVVIk',
#   'id': {'kind': 'youtube#video', 'videoId': 'EPUayNC5ku4'},
#   'snippet': {'publishedAt': '2020-11-19T08:00:05Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'SQL Coding Interview Question Using A Window Function (PARTITION BY) | Data Science Interviews',
#    'description': "In this video, I'll walk you through a common SQL coding interview question that is asked in many data science interviews.",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/EPUayNC5ku4/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/EPUayNC5ku4/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/EPUayNC5ku4/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-11-19T08:00:05Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'FOxlfyQoK13WxY5RC0V2m4hfG6c',
#   'id': {'kind': 'youtube#video', 'videoId': 'wqBFgaMgFQA'},
#   'snippet': {'publishedAt': '2020-11-15T08:00:10Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Solve Data Science Tasks In Python (Saving Hours) (automating import CSV files to database)',
#    'description': "Solving real world data science tasks by automating this common data science task will save you hours of work. I'll cover how to ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wqBFgaMgFQA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/wqBFgaMgFQA/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/wqBFgaMgFQA/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-11-15T08:00:10Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'd5lNxKgaxR9DRFawg9RABL1cxXQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'IKw0lkmBHNI'},
#   'snippet': {'publishedAt': '2020-11-11T08:00:06Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Solving an Airbnb Data Science Coding Interview Question | SQL Interview  [Fav Host Nationality]',
#    'description': "This SQL data science interview question was asked by Airbnb. I'll cover both the question and answer and give a detailed ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/IKw0lkmBHNI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/IKw0lkmBHNI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/IKw0lkmBHNI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-11-11T08:00:06Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'ONkTSK_yMV5LFzXm0JrSBJ8Vlow',
#   'id': {'kind': 'youtube#video', 'videoId': '_gy1o9UH2dQ'},
#   'snippet': {'publishedAt': '2020-11-04T08:00:04Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Hard SQL Interview Question From FACEBOOK | Data Science Coding Interviews (Popularity Percentage)',
#    'description': "This SQL data science interview question was asked by Facebook. I'll cover both the question and answer and give a detailed ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/_gy1o9UH2dQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/_gy1o9UH2dQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/_gy1o9UH2dQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-11-04T08:00:04Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '00C_n3Pwkdo-JauDL1cUq5MZZe8',
#   'id': {'kind': 'youtube#video', 'videoId': '7Q-2DEwHW7w'},
#   'snippet': {'publishedAt': '2020-10-29T07:00:03Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Solving a SQL Interview Question by FACEBOOK | (Data Science Interview) SMS Confirmations From Users',
#    'description': "This SQL data science interview question was asked by Facebook. I'll cover both the question and answer and give a detailed ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7Q-2DEwHW7w/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/7Q-2DEwHW7w/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/7Q-2DEwHW7w/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-29T07:00:03Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '_ZgrFTzGWBg_H1kDnPqhdHoRjeg',
#   'id': {'kind': 'youtube#video', 'videoId': 'pFwYjaeKFvQ'},
#   'snippet': {'publishedAt': '2020-10-22T07:00:06Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Solving a Facebook Data Science Interview Questions | (SQL Interview Questions and Answer)',
#    'description': "This SQL data science interview question was asked by Facebook. I'll cover both the question and answer and give a detailed ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/pFwYjaeKFvQ/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/pFwYjaeKFvQ/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/pFwYjaeKFvQ/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-22T07:00:06Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': '1L7ZuTkLhb4tet_ZGsZlLyQcHlQ',
#   'id': {'kind': 'youtube#video', 'videoId': 'iR8FDQyCtnw'},
#   'snippet': {'publishedAt': '2020-10-20T07:00:05Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'SQL Interview Questions From MICROSOFT | Expensive Projects (Data Science Interview Questions)',
#    'description': "This SQL data science interview question was asked by Microsoft. I'll cover both the question and answer and give a detailed ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/iR8FDQyCtnw/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/iR8FDQyCtnw/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/iR8FDQyCtnw/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-20T07:00:05Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'WTSVmLa04UasCVYQ97vceVCuw7k',
#   'id': {'kind': 'youtube#video', 'videoId': '1SgHHQeRuxs'},
#   'snippet': {'publishedAt': '2020-10-18T15:59:35Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'How I Prepare For My Data Science Interviews (From a Data Scientist)',
#    'description': "Hi Everyone! I've been wanting to make a video where I talk about how I prepare for MY data science interviews so you know how ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/1SgHHQeRuxs/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/1SgHHQeRuxs/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/1SgHHQeRuxs/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-18T15:59:35Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'zkL-xkNhirvXpiQVc5KjLu-wvFo',
#   'id': {'kind': 'youtube#video', 'videoId': 'UndSRKwsxKM'},
#   'snippet': {'publishedAt': '2020-10-10T07:00:04Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'YELP SQL Data Science Interview Questions | Common Coding Question (Mock Interview Walkthrough)',
#    'description': "This SQL data science interview question was asked by Yelp. I'll cover both the question and answer and give a detailed ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UndSRKwsxKM/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/UndSRKwsxKM/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/UndSRKwsxKM/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-10-10T07:00:04Z'}},
#  {'kind': 'youtube#searchResult',
#   'etag': 'fXfJD-Pk3fkkFYKNod0FIxz1G_0',
#   'id': {'kind': 'youtube#video', 'videoId': 'U9P4M4EPTgI'},
#   'snippet': {'publishedAt': '2020-09-23T07:00:04Z',
#    'channelId': 'UCW8Ews7tdKKkBT6GdtQaXvQ',
#    'title': 'Intro to Real Data Science Interview Questions and Answers Series (Interview Walkthroughs)',
#    'description': "Hey Everyone! I just wanted to introduce a new set of videos where I'll walk through data science interview questions from real ...",
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/U9P4M4EPTgI/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/U9P4M4EPTgI/mqdefault.jpg',
#      'width': 320,
#      'height': 180},
#     'high': {'url': 'https://i.ytimg.com/vi/U9P4M4EPTgI/hqdefault.jpg',
#      'width': 480,
#      'height': 360}},
#    'channelTitle': 'StrataScratch',
#    'liveBroadcastContent': 'none',
#    'publishTime': '2020-09-23T07:00:04Z'}}]

# %% [markdown]
# Next, going through the attributes that I'm interested in saving and for this example I'l be saving the video id in a **variable**. Therefore, starting from the outer key, 'items', I drill down to the key 'id' and finally select 'videoId'. The process is repeated for the rest of the variables.
#
# In this case only the first video, number 0, is selected. To generalize for all the videos an **iterative process** will be used.

# %%
video_id = response['items'][0]['id']['videoId']

video_title = response['items'][0]['snippet']['title']
#replacing the '&' symbol with a blank
video_title = str(video_title).replace("&amp;","")

upload_date = response['items'][0]['snippet']['publishedAt']
#to remove the timezone inormation I split on the "T" and save everything to the left of the 0
upload_Date = str(upload_date).split("T")[0]

# %% [markdown]
# Creating a **for loop** to iterate the above process for all the videos in the channel.
#
# Through the placeholder variable 'video' I go through every video in the array response['items'] and grab the relevant information.

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;","")

        upload_date = video['snippet']['publishedAt']
        upload_Date = str(upload_date).split("T")[0]

# %% [markdown]
# However, the data in this API call doesn't have any information on the views, likes, dislikes etc. statistics and a **second separate API call** is necessary.
#
# To grab all of the video information this URL takes the video_id extracted above as a parameter. The second parameter is the API key.
# The statistics extracted are:
# * View count
# * Like count
# * Favourite count
# * Comment count

# %%
url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY

response_video_stats = requests.get(url_video_stats).json()

view_count = response_video_stats['items'][0]['statistics']['viewCount']
like_count = response_video_stats['items'][0]['statistics']['likeCount']
favorite_count = response_video_stats['items'][0]['statistics']['favoriteCount']
comment_count = response_video_stats['items'][0]['statistics']['commentCount']

# %% [markdown]
# These statistics will be extracted for every video (unique video id) and therefore should be inserted in the previous for loop, that is rewritten below.

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;","")

        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_date).split("T")[0]

        # extract views, likes, favourites and number of comments
        url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY

        response_video_stats = requests.get(url_video_stats).json()

        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        favorite_count = response_video_stats['items'][0]['statistics']['favoriteCount']
        comment_count = response_video_stats['items'][0]['statistics']['commentCount']

# %% [markdown]
# With the above code the variables are overwritten with every iteration, therefore a data frame is created to save all the relevant data for every video.
# The data frame has 7 columns, corresponding to the collected variables.

# %%
df= pd.DataFrame(columns=['video_id', 'video_title', 'upload_date', 'view_count', 'like_count', 'favorite_count', 'comment_count'])

# %% [markdown]
# **Append method**
#
# An empty data frame has been created and all there's left is to store the data in the table.
# The append() method comes in handy, as with every iteration it will modify the dataframe and add a new line with the details of every video at the end.

# %%
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id = video['id']['videoId']
        
        video_title = video['snippet']['title']
        video_title = str(video_title).replace("&amp;","")

        upload_date = video['snippet']['publishedAt']
        upload_date = str(upload_date).split("T")[0]

        # extract views, likes, favourites and number of comments
        url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY

        response_video_stats = requests.get(url_video_stats).json()

        view_count = response_video_stats['items'][0]['statistics']['viewCount']
        like_count = response_video_stats['items'][0]['statistics']['likeCount']
        favorite_count = response_video_stats['items'][0]['statistics']['favoriteCount']
        comment_count = response_video_stats['items'][0]['statistics']['commentCount']

        df = df.append({'video_id': video_id, 'video_title': video_title, 'upload_date': upload_date, 'view_count' : view_count, 'like_count' : like_count, 'favorite_count' : favorite_count, 'comment_count' : comment_count}, ignore_index = True)

# %% [markdown]
# Implementing **good Software Engineering fundamentals**
#
# The API calls are mixed within the for loop.To make the code clearer and more slimple the API calls can be broken down into several smaller blocks, with the use of functions.

# %%
#import libraries
import requests
import pandas as pd
import time

# %%
#Keys
API_KEY = "AIzaSyAtW9XIp79rBPcUf_Cb7P1GIsrimYtEBRs"
CHANNEL_ID  = "UCZdQjaSoLjIzFnWsDQOv4ww"

# %% [markdown]
# The part within the for loop where the video details are extracted is transformed into a function returning the count metrics.

# %%
def get_video_details(video_id):
    # extract views, likes, favourites and number of comments
    url_video_stats = "https://www.googleapis.com/youtube/v3/videos?id="+video_id+"&part=statistics&key="+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    favorite_count = response_video_stats['items'][0]['statistics']['favoriteCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']

    return view_count, like_count, favorite_count, comment_count

# %% [markdown]
# The rest of the for loop is transformed get_videos function, which has a data rame as an input. The function will extract the metrics for every video of the channel and append it to the dataframe.
#
# There is a chance that the iteration of the for loop will start before the data are collected with the API. To avoid that the time.sleep() function is used to stall the for loop for 1 second and make sure that all data are stored in the response variable.

# %%
def get_videos(df):
    #make API call
    pageToken = ""
    url = "https://www.googleapis.com/youtube/v3/search?key="+API_KEY+"&channelId="+CHANNEL_ID+"&part=snippet,id&order=date&maxResults=10000&"+pageToken

    response = requests.get(url).json()
    time.sleep(1) #give it a second before starting the for loop

    for video in response['items']:
        if video['id']['kind'] == "youtube#video":
            video_id = video['id']['videoId']
            video_title = video['snippet']['title']
            video_title = str(video_title).replace("&amp;","")
            upload_date = video['snippet']['publishedAt']
            upload_date = str(upload_date).split("T")[0]
            
            view_count, like_count, favourite_count, comment_count = get_video_details(video_id)

            df = df.append({'video_id':video_id,'video_title':video_title,
                            "upload_date":upload_date,"view_count":view_count,
                            "like_count":like_count,"favourite_count":favourite_count,
                            "comment_count":comment_count},ignore_index=True)
    return df

# %% [markdown]
# The functions are created and the below portion is the main code where the functions are called and the data frame is created.

# %%
#main

#build our dataframe
df = pd.DataFrame(columns=["video_id","video_title","upload_date","view_count","like_count","favourite_count","comment_count"]) 

df = get_videos(df)

# %%
df.describe()
# Out:
#            video_id                          video_title upload_date  \
# count            50                                   50          50
# unique           50                                   50          50
# top     ESjPKurqcC0  HOW I QUIT MY JOB TO SAIL THE WORLD  2022-05-09
# freq              1                                    1           1
#
#        view_count like_count favourite_count comment_count
# count          50         50              50            50
# unique         50         50               1            48
# top        339237      27080               0          1139
# freq            1          1              50             2

# %% [markdown]
# This concludes the first part of the project. For the next part I will be uploading the above data frame on a database.
#
# To be continued...
